# %% [markdown]
# ### **1. Distribuzioni di probabilità**
# Genera 1000 valori casuali da una distribuzione gamma con parametro di forma pari a 1.
# Suggerimento: il parametro di forma viene passato come primo argomento quando si "congela" la distribuzione.
#
# Traccia l’istogramma del campione e sovrapponi la PDF della distribuzione.
#
# Stima il parametro di forma dal campione usando il metodo fit.
#
# Extra:
# Le distribuzioni hanno molti metodi utili. Esplorali usando il completamento automatico con il tasto TAB.
#
# Traccia la funzione di distribuzione cumulativa (CDF).
#
# Calcola la varianza.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp

gamma_dist = sp.stats.gamma(1) #distribuzione congelata
sample = gamma_dist.rvs(size=1000) #genera 1000 valori
plt.hist(sample, bins=30, density=True) #istogramma
x = np.linspace(0, max(sample), 100) #PDF
plt.plot(x, gamma_dist.pdf(x))
plt.show()
print(sp.stats.gamma.fit(sample)) #parametro
#extra
plt.plot(x, gamma_dist.cdf(x))
plt.show()
print(gamma_dist.var()) #varianza
# Out:
# (np.float64(1.040901258197211), np.float64(0.002739413005363546), np.float64(0.9807814409000288))
# 1.0

# %% [markdown]
# ### **2. Fitta i dati**
# Prova a fittare i dati sottostanti con le migliori curve, calcola il MAE e l'RMSE
# Esercizio

# %%
import numpy as np
temp_max = np.array([17, 19, 21, 28, 33, 38, 37, 37, 31, 23, 19, 18])
temp_min = np.array([-62, -59, -56, -46, -32, -18, -9, -13, -25, -46, -52, -58])
import matplotlib.pyplot as plt

x = np.arange(len(temp_max))
coef_max = np.polyfit(x, temp_max, 2)
coef_min = np.polyfit(x, temp_min, 2)
poly_max = np.poly1d(coef_max)
poly_min = np.poly1d(coef_min)
pred_max = poly_max(x)
pred_min = poly_min(x)
mae_max = np.mean(np.abs(temp_max - pred_max))
mae_min = np.mean(np.abs(temp_min - pred_min))
rmse_max = np.sqrt(np.mean((temp_max - pred_max) ** 2))
rmse_min = np.sqrt(np.mean((temp_min - pred_min) ** 2))
print("MAX")
print("MAE:", mae_max)
print("RMSE:", rmse_max)
print("\nMIN")
print("MAE:", mae_min)
print("RMSE:", rmse_min)
plt.plot(x, temp_max, "o", label="Temp max reali")
plt.plot(x, pred_max, label="Fit max")
plt.plot(x, temp_min, "o", label="Temp min reali")
plt.plot(x, pred_min, label="Fit min")
plt.title("Fit temperature")
plt.xlabel("Mese")
plt.ylabel("Temperatura")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# MAX
# MAE: 2.581793206793201
# RMSE: 2.9601604601862292
#
# MIN
# MAE: 7.52097902097902
# RMSE: 8.533903317211054

# %% [markdown]
# ### **3. Modello di regressione lineare dei seguenti dati**
#
#  Calcola un modello di regressione lineare delle colonne mpg e disp del famoso dataset mtcars.
#
# Dove:
#
# mpg = Miles Per Gallon → miglia per gallone, cioè una misura del consumo di carburante. Più alto è il valore, più efficiente è l’auto.
#
# disp = Displacement → cilindrata del motore, in pollici cubici (cubic inches). Rappresenta il volume totale dei cilindri del motore. Più è alto, maggiore è la potenza potenziale del motore (ma anche il consumo).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# Load dataset from URL
df = pd.read_csv('https://gist.githubusercontent.com/seankross/a412dfbd88b3db70b74b/raw/5f23f993cd87c283ce766e7ac6b329ee7cc2e1d1/mtcars.csv')
# Display the dataframe
df
x = df["disp"]
y = df["mpg"]
slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
y_pred = intercept + slope * x
mae = np.mean(np.abs(y - y_pred))
rmse = np.sqrt(np.mean((y - y_pred) ** 2))
print("Intercept:", intercept)
print("Slope:", slope)
print("MAE:", mae)
print("RMSE:", rmse)
plt.scatter(x, y)
plt.plot(x, y_pred)
plt.title("Regressione lineare: mpg vs disp")
plt.xlabel("disp")
plt.ylabel("mpg")
plt.show()
# Out:
# Intercept: 29.59985475616395
# Slope: -0.04121511996278614
# MAE: 2.605473485761068
# RMSE: 3.1482072740002796
